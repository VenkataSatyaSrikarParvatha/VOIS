# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("car_Dekho_DA.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#From which manufacturing year to which manufacturing year vehicles are present in this data ?
#What is the lowest price to which a vehicle is sold ?
#What is the highest price to which a vehicle is sold ?
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#How many records are there in this data ?
df.shape
# Out:
# (301, 9)

# %%
#Are there any missing records in this data ?
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#How many different vehicles are present in this data ?
df["Car_Name"].nunique()
# Out:
# 98

# %%
#Which is the most sold vehicle in this data ?
df["Car_Name"].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
#Does the database include any CNG vehicle ? If yes how many of them are there ?
df["Fuel_Type"].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
#How many vehicles here are for sell from Individuals directly ?
df["Seller_Type"].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df.value_counts()
# Out:
# Car_Name           Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# fortuner           2015  23.00          30.61          40000       Diesel     Dealer       Automatic     0        2
# ertiga             2016  7.75           10.79          43000       Diesel     Dealer       Manual        0        2
# 800                2003  0.35           2.28           127000      Petrol     Individual   Manual        0        1
# ertiga             2015  6.10           7.71           26000       Petrol     Dealer       Manual        0        1
# etios g            2014  4.75           6.76           40000       Petrol     Dealer       Manual        0        1
#                                                                                                                  ..
# Yamaha FZ S V 2.0  2015  0.55           0.84           58000       Petrol     Individual   Manual        0        1
# ...

# %%
df.count()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
#How many single owned persons are there ?
df["Owner"].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
#Highest Depreciation from the data
df["Dep"]=df["Present_Price"] - df["Selling_Price"]
df.loc[df.Dep == df.Dep.max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Seller_Type Transmission  Owner   Dep
# 86      Dealer       Manual      0  57.6

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner   Dep
# 0      Dealer       Manual      0  2.24
# 1      Dealer       Manual      0  4.79
# 2      Dealer       Manual      0  2.60
# 3      Dealer       Manual      0  1.30
# 4      Dealer       Manual      0  2.27

# %%
#lowest Depreciation from the data
df.loc[df.Dep == df.Dep.min()]
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
#
#     Fuel_Type Seller_Type Transmission  Owner   Dep
# 155    Petrol  Individual    Automatic      0  0.03

# %%
plt.figure(figsize=(12, 20))
sns.boxplot(x='Dep', y='Car_Name', data=df)
plt.xticks(rotation=90)
plt.title('Depreciation by Vehicle Brand')
plt.xlabel('Depreciation (Dep)')
plt.ylabel('Car Name')
plt.show()
#the smaller boxes are less affected by cost depreciation

# %%
#How does the resale value (selling price) vary with the fuel type (Petrol, Diesel, CNG)?
plt.scatter(df.Selling_Price,df.Fuel_Type)
plt.show()

# %%
#Is there a significant difference in depreciation between vehicles sold by dealers versus individuals?
plt.figure(figsize=(10, 6))
sns.boxplot(x='Seller_Type', y='Dep', data=df)
plt.title('Depreciation by Seller Type')
plt.xlabel('Seller Type')
plt.ylabel('Depreciation (Dep)')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df.Fuel_Type.value_counts(),labels=["Petrol","Disel","CNG"],shadow=True)
plt.show()

# %%
df.Fuel_Type.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
df.Owner.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Owner'>

# %%
plt.scatter(df.Kms_Driven ,df.Selling_Price)
plt.xlabel("Kilometres Driven")
plt.ylabel("Selling Price in lak")
plt.title("Selling price vs Kilometers Driven")
plt.show()

# %%
plt.scatter(df.Year ,df.Selling_Price)
plt.xlabel("Years")
plt.ylabel("Selling Price in lak")
plt.title("Selling price vs Years")
plt.show()

# %%
#After 2014, how many vechicals are manufactured
xdf = df.loc[df['Year'] >= 2014]
xdf.head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
#
#   Seller_Type Transmission  Owner   Dep
# 0      Dealer       Manual      0  2.24
# 2      Dealer       Manual      0  2.60
# 4      Dealer       Manual      0  2.27
# 5      Dealer       Manual      0  0.58
# 6      Dealer       Manual      0  1.37

# %%
#resetting the index numbers of desired table
xdf.reset_index(drop= True, inplace = True)
xdf
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1             ciaz  2017           7.25           9.85        6900    Petrol
# 2            swift  2014           4.60           6.87       42450    Diesel
# 3    vitara brezza  2018           9.25           9.83        2071    Diesel
# 4             ciaz  2015           6.75           8.12       18796    Petrol
# ..             ...   ...            ...            ...         ...       ...
# 180           city  2015           8.55          13.09       60076    Diesel
# 181           city  2016           9.50          11.60       33988    Diesel
# 182           brio  2015           4.00           5.90       60000    Petrol
# 183           city  2017          11.50          12.50        9000    Diesel
# 184           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner   Dep
# ...

# %%
#Two wheelers from the data
twh =df[df["Present_Price"] < 3.5]
twh.head()
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 23                    alto k10  2014           2.50           3.46
# 37                         800  2003           0.35           2.28
# 44                        omni  2012           1.25           2.69
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner   Dep
# 23        45280    Petrol      Dealer       Manual      0  0.96
# 37       127000    Petrol  Individual       Manual      0  1.93
# 44        50000    Petrol      Dealer       Manual      0  1.44
# 100        3000    Petrol  Individual       Manual      0  0.15
# 101        1400    Petrol  Individual       Manual      0  0.12

# %%
twh.reset_index(drop =True,inplace=True)
twh.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0                   alto k10  2014           2.50           3.46       45280
# 1                        800  2003           0.35           2.28      127000
# 2                       omni  2012           1.25           2.69       50000
# 3  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 4         UM Renegade Mojave  2017           1.70           1.82        1400
#
#   Fuel_Type Seller_Type Transmission  Owner   Dep
# 0    Petrol      Dealer       Manual      0  0.96
# 1    Petrol  Individual       Manual      0  1.93
# 2    Petrol      Dealer       Manual      0  1.44
# 3    Petrol  Individual       Manual      0  0.15
# 4    Petrol  Individual       Manual      0  0.12

# %%
twh = twh.loc[twh.Car_Name !="alto k10"]
twh=twh.loc[twh.Car_Name !="800"]
twh = twh.loc[twh.Car_Name !="omni"]
twh
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 3    Royal Enfield Thunder 500  2016           1.75           1.90
# 4           UM Renegade Mojave  2017           1.70           1.82
# 5                    KTM RC200  2017           1.65           1.78
# 6            Bajaj Dominar 400  2017           1.45           1.60
# 7    Royal Enfield Classic 350  2017           1.35           1.47
# ..                         ...   ...            ...            ...
# 99                   Activa 3g  2008           0.17           0.52
# 100           Honda CB twister  2010           0.16           0.51
# 101         Bajaj Discover 125  2011           0.15           0.57
# 102             Honda CB Shine  2007           0.12           0.58
# 103           Bajaj Pulsar 150  2006           0.10           0.75
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner   Dep
# 3          3000    Petrol  Individual       Manual      0  0.15
# ...

# %%
#which is the oldest and newest bike here ?
twh.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner  \
# count   101.000000     101.000000     101.000000     101.000000  101.000000
# mean   2013.702970       0.640792       0.990297   28120.128713    0.059406
# std       2.913913       0.389722       0.512189   54059.166731    0.237562
# min    2005.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.380000       0.580000    7000.000000    0.000000
# 50%    2014.000000       0.500000       0.840000   18000.000000    0.000000
# 75%    2016.000000       0.900000       1.200000   31000.000000    0.000000
# max    2017.000000       1.750000       3.450000  500000.000000    1.000000
#
#               Dep
# count  101.000000
# mean     0.349505
# std      0.286098
# min      0.030000
# 25%      0.150000
# 50%      0.310000
# 75%      0.450000
# max      2.100000

# %%
#which is the most sold bike ?
twh["Car_Name"].value_counts()
# Out:
# Car_Name
# Royal Enfield Classic 350    7
# Bajaj Pulsar 150             4
# Royal Enfield Thunder 350    4
# Bajaj Pulsar NS 200          3
# TVS Apache RTR 160           3
#                             ..
# TVS Sport                    1
# Honda Dream Yuga             1
# Bajaj Avenger Street 220     1
# Honda CB Trigger             1
# Bajaj  ct 100                1
# Name: count, Length: 61, dtype: int64

# %%
twh.loc[twh.Year == twh.Year.min()]
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 92  Hero Super Splendor  2005            0.2           0.57       55000
#
#    Fuel_Type Seller_Type Transmission  Owner   Dep
# 92    Petrol  Individual       Manual      0  0.37

# %%
twh.loc[twh.Year == twh.Year.max()]
# Out:
#                      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 4          UM Renegade Mojave  2017           1.70           1.82        1400
# 5                   KTM RC200  2017           1.65           1.78        4000
# 6           Bajaj Dominar 400  2017           1.45           1.60        1200
# 7   Royal Enfield Classic 350  2017           1.35           1.47        4100
# 12  Royal Enfield Classic 350  2017           1.20           1.47       11000
# 29          Bajaj Avenger 220  2017           0.90           0.95        1300
# 31       Honda CB Hornet 160R  2017           0.80           0.87        3000
# 32          Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 33       Honda CB Hornet 160R  2017           0.75           0.87       11000
# 35          Bajaj Avenger 220  2017           0.75           0.95        3500
# 37         TVS Apache RTR 160  2017           0.65           0.81       11800
# ...

# %%
#To check whether any deal about two wheelers exceeded general expectations
plt.boxplot(twh.Selling_Price)
plt.show()

# %%
import seaborn as sns

# %%
fig_dims =(12,20)
fig ,ax = plt.subplots(figsize =fig_dims)
sns.countplot(y=twh.Car_Name, ax=ax, data=twh)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %%
#Table for four wheelers
cars = df[df["Present_Price"] >=3.5]
cars
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner   Dep
# 0        Dealer       Manual      0  2.24
# ...

# %%
#resetting index for cars table
cars.reset_index(drop=True , inplace=True)
cars
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 192     city  2016           9.50          11.60       33988    Diesel
# 193     brio  2015           4.00           5.90       60000    Petrol
# 194     city  2009           3.35          11.00       87934    Petrol
# 195     city  2017          11.50          12.50        9000    Diesel
# 196     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner   Dep
# 0        Dealer       Manual      0  2.24
# ...

# %%
#which is the oldest car here ?
cars.loc[cars.Year == cars.Year.min()]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 37      sx4  2003           2.25           7.98       62000    Petrol
#
#    Seller_Type Transmission  Owner   Dep
# 37      Dealer       Manual      0  5.73

# %%
#which is the newest car here ?
cars.loc[cars.Year == cars.Year.max()]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
#
#   Seller_Type Transmission  Owner   Dep
# 5      Dealer       Manual      0  0.58

# %%
#To check whether any deal about Four wheelers exceeded general expectations
plt.boxplot(cars.Selling_Price)
plt.show()

# %%
fig_dims =(12,20)
fig ,ax = plt.subplots(figsize =fig_dims)
sns.countplot(y=cars.Car_Name, ax=ax, data=cars)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>
